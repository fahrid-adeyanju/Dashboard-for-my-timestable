# %% [markdown]
# <a href="https://colab.research.google.com/github/fahrid-adeyanju/Dashboard-for-my-timestable/blob/codespace-automatic-space-broccoli-4jw5r9675474hg54/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Weather App for Andover
#
# This notebook will demonstrate how to fetch and display current weather information for Andover using a public weather API. You will need an API key from a service like OpenWeatherMap.

# %%
# Install the requests library if you don't have it already
# !pip install requests

# %%
import requests
from google.colab import userdata

# Retrieve the API key from Colab secrets
OPENWEATHER_API_KEY = userdata.get('OPENWEATHER_API_KEY')

if not OPENWEATHER_API_KEY:
    raise ValueError("Please set your OpenWeatherMap API key in Colab secrets as 'OPENWEATHER_API_KEY'.")

# %%
def get_weather(city, api_key):
    base_url = "http://api.openweathermap.org/data/2.5/weather"
    params = {
        'q': city,
        'appid': api_key,
        'units': 'metric'  # Use 'imperial' for Fahrenheit
    }
    response = requests.get(base_url, params=params)
    response.raise_for_status() # Raise an exception for HTTP errors
    return response.json()

def display_weather(weather_data):
    if weather_data:
        city = weather_data['name']
        country = weather_data['sys']['country']
        temperature = weather_data['main']['temp']
        feels_like = weather_data['main']['feels_like']
        description = weather_data['weather'][0]['description']
        humidity = weather_data['main']['humidity']
        wind_speed = weather_data['wind']['speed']

        print(f"Current Weather in {city}, {country}:")
        print(f"Temperature: {temperature}°C (Feels like: {feels_like}°C)")
        print(f"Conditions: {description.capitalize()}")
        print(f"Humidity: {humidity}%")
        print(f"Wind Speed: {wind_speed} m/s")
    else:
        print("Could not retrieve weather data.")

# %%
# Get and display weather for Andover
andover_weather = get_weather('Andover', OPENWEATHER_API_KEY)
display_weather(andover_weather)
# Out:
# Current Weather in Andover, GB:
# Temperature: 24.27°C (Feels like: 24.61°C)
# Conditions: Broken clouds
# Humidity: 71%
# Wind Speed: 5.14 m/s

# %% [markdown]
# ## Deploying to GitHub
#
# To share this notebook on GitHub, you can follow these general steps:
#
# 1.  **Save the Notebook**: Make sure you have saved all changes in your Google Colab notebook.
#     *   Go to `File` > `Save a copy in GitHub` (if you've already linked your GitHub account) or `File` > `Download` > `Download .ipynb` to save it locally.
#
# 2.  **Create a GitHub Repository**: If you don't already have one, create a new repository on GitHub.
#     *   Go to [GitHub](https://github.com/) and log in.
#     *   Click on the `+` sign in the top right corner and select `New repository`.
#     *   Give your repository a name (e.g., `WeatherApp`), an optional description, and choose whether it's public or private. Make sure to initialize it with a README.
#
# 3.  **Upload the Notebook**: If you downloaded the `.ipynb` file, you can upload it to your new GitHub repository.
#     *   Navigate to your new repository on GitHub.
#     *   Click on the `Add file` button and select `Upload files`.
#     *   Drag and drop your `.ipynb` file into the upload area or click `choose your files`.
#     *   Add a commit message and click `Commit changes`.
#
# 4.  **Share the Link**: Once the notebook is on GitHub, you can share the direct link to the `.ipynb` file or the repository with your dad. GitHub will render the notebook content directly in the browser.
#
# Your dad will be able to view the code and explanations. If he wants to run it, he can open it directly in Colab from GitHub (look for the 'Open in Colab' badge on the GitHub page if available, or instruct him to go to `File` > `Open notebook` > `GitHub` in Colab and paste the repository URL).
